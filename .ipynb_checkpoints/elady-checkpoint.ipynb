# %%
import undetected_chromedriver as uc
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import csv
from datetime import datetime
from requests.auth import HTTPProxyAuth
import requests

# %%
proxy_host = '184.174.24.237'  
proxy_port = '6813'              
proxy_username = 'fjhdetvm'  
proxy_password = 'dj626ier4ofb'  

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

page_url = 'https://mall.elady.com/items/category/BAGS/?limit=120'

proxy_url = f'http://{proxy_username}:{proxy_password}@{proxy_host}:{proxy_port}'

current_time = datetime.now().strftime('%Y-%m-%d_%H-%M-%S')
csv_file = f'elady_{current_time}.csv'

def product_info(product_url, retry = 3):
    if retry ==0:
        return None
    try:
        if not product_url.startswith('http'):
            raise ValueError("Invalid product URL")
        
        response = requests.get(product_url, proxies={'http': proxy_url, 'https': proxy_url}, headers=headers,auth=HTTPProxyAuth(proxy_username, proxy_password))
        if response.status_code != 200:
            raise Exception(f"Failed to retrieve {product_url}, status code: {response.status_code}")
            
        soup = BeautifulSoup(response.content, 'html.parser')
        
        product_name = soup.find('div',class_='detail__name').text.strip()

        product_price = soup.find('span',class_='price').text.strip()

        sku = soup.find('p',class_='detail__code').text.replace('SKU:','').strip()

        main_image = soup.find('img',id='image-main').get('src')

        brand, line, product_type, material, color, closure, inner_pocket, gender, size, handle_length, strap_length = None, None, None, None, None, None, None, None, None, None, None 
        all_x_td = soup.find('div', id = 'detail_param_content1').find_all('td', class_='y')
        all_x_td = [i for i in all_x_td if i.text != '']
        all_y_td = soup.find('div', id = 'detail_param_content1').find_all('td', class_='x')
        for num in range(len(all_x_td)):
            key = all_x_td[num].text
            values = all_y_td[num].find_all('tr')
            if len(values)>1:
                value = ', '.join([i.text.strip() for i in values if hasattr(i, 'text') and i.text != '']).strip()
            else:
                value = values[0].text.strip()

            if key == 'Brand':
                brand = value
            elif key == 'Line':
                line = value
            elif key == 'Model':
                model = value
            elif key == 'Country of Origin':
                country_of_origin = value
            elif key == 'Type':
                product_type = value
            elif key == 'Material':
                material = value
            elif key == 'Leather/Fur Type':
                leather_or_fur_type = value
            elif key == 'Color':
                color = value
            elif key == 'Closure':
                closure = value
            elif key == 'Inner Pocket':
                inner_pocket = value
            elif key == 'Gender':
                gender = value
            elif key == 'Size (HxWxD)':
                size = value
            elif key == 'Handle Length':
                handle_length = value
            elif key == 'Strap Length':
                strap_length = value

        all_x_td = soup.find('div', id = 'detail_param_content2').find_all('td', class_='y')
        all_x_td = [i for i in all_x_td if i.text != '']
        all_y_td = soup.find('div', id = 'detail_param_content2').find_all('td', class_='x')

        accessories, condition = None, None
        for num in range(len(all_x_td)):
            key = all_x_td[num].text
            values = all_y_td[num].find_all('tr')
            if len(values)>1:
                value = ', '.join([i.text.strip() for i in values if hasattr(i, 'text') and i.text != '']).strip()
            else:
                value = values[0].text.strip()

            if key == 'Accessories':
                accessories = value
            elif key == 'Condition':
                condition = value

        di = {'product_name':product_name, 'product_price':product_price, 'sku':sku, 'main_image':main_image,
         'brand':brand, 'line':line, 'model':model, 'country_of_origin':country_of_origin, 'product_type':product_type, 'material':material, 
              'leather_or_fur_type':leather_or_fur_type, 'color':color, 'closure':closure,
          'inner_pocket':inner_pocket, 'gender':gender, 'size':size, 'handle_length':handle_length, 'strap_length':strap_length,
             'accessories':accessories, 'condition':condition}
        return di
    
    except Exception as e:
        print(f"Error in product_info for {product_url}: {e}")
        print('Retrying this URL again!!, Remaining retry: ',retry)
        return product_info(product_url, retry-1)
        
    

with open(csv_file, mode='w', newline='', encoding='utf-8') as file:
    
    fieldnames = ['product_name', 'product_price', 'sku', 'main_image', 'brand', 'line', 'model', 'country_of_origin', 'product_type', 'material', 
                  'leather_or_fur_type', 'color',
                  'closure', 'inner_pocket', 'gender', 'size', 'handle_length', 'strap_length', 'accessories', 'condition']
    
    writer = csv.DictWriter(file, fieldnames=fieldnames)

    # Write the header row once
    writer.writeheader()
    
    while True:
        try:
            response = requests.get(page_url, proxies={'http': proxy_url, 'https': proxy_url}, headers=headers,auth=HTTPProxyAuth(proxy_username, proxy_password))
            if response.status_code != 200:
                raise Exception(f"Failed to retrieve page, status code: {response.status_code}")

            soup = BeautifulSoup(response.content, 'html.parser')
            try:
                page_url = 'https://mall.elady.com'+soup.find('a', title='Next').get('href')
            except:
                page_url = None

            if page_url == None:
                break

            urls = soup.find_all('a', class_='item_archive__link')

            for url in urls:
                product_url = 'https://mall.elady.com' + url.get('href')
                print(product_url)
                product_data = product_info(product_url)
                
                if product_data:
                    writer.writerow(product_data)
                    file.flush()  
                    
                length = sum(1 for _ in open(csv_file)) - 1  # Subtract 1 to exclude the header
                print(f"Current CSV length (excluding header): {length}")

        except Exception as e:
            print(f"Error while processing page: {e}")
            break
# Out:
# https://mall.elady.com/item/title/Bottega-Veneta-Intrecciato-Cassette-WomenMen-Leather-Sling-Bag-White-BF576446
# Current CSV length (excluding header): 1
# https://mall.elady.com/item/title/Bottega-Veneta-Intrecciato-Cassette-MenWomen-Leather-Clutch-Bag-Light-Beige-BF576443
# Current CSV length (excluding header): 2
# https://mall.elady.com/item/title/Louis-Vuitton-Damier-Neverfull-MM-N41603-Womens-Tote-Bag-Rose-BallerineEbene-BF576464
# Current CSV length (excluding header): 3
# https://mall.elady.com/item/title/Louis-Vuitton-Monogram-Cabas-Mezzo-M51151-Womens-Tote-Bag-Brown-BF576455
# Current CSV length (excluding header): 4
# https://mall.elady.com/item/title/Bottega-Veneta-Large-The-Arco-Tote-MenWomen-Leather-Tote-Bag-Light-Blue-BF576348
# Current CSV length (excluding header): 5
# https://mall.elady.com/item/title/Louis-Vuitton-Monogram-Cabas-Piano-M51148-Womens-Tote-Bag-Monogram-BF576456
# Current CSV length (excluding header): 6
# https://mall.elady.com/item/title/Louis-Vuitton-Damier-Reggia-N63542-Womens-Shoulder-Bag-Ebene-BF576378
# Current CSV length (excluding header): 7
# https://mall.elady.com/item/title/Louis-Vuitton-Monogram-Vernis-Reade-PM-M91145-Womens-Handbag-Gris-BF576462
# Current CSV length (excluding header): 8
# https://mall.elady.com/item/title/Prada-Womens-Leather-Boston-BagHandbag-Black-BF576349
# Current CSV length (excluding header): 9
# https://mall.elady.com/item/title/Chlo-Pixie-Womens-LeatherSuede-Shoulder-Bag-Beige-BF576357
# Current CSV length (excluding header): 10
# https://mall.elady.com/item/title/Gucci-Old-Gucci-000-926-0211-Womens-Leather-HandbagShoulder-Bag-Black-BF576433
# Current CSV length (excluding header): 11
# https://mall.elady.com/item/title/Fendi-Chameleon-Chameleon-Leather-Handbag-Black-BF576362
# Current CSV length (excluding header): 12
# https://mall.elady.com/item/title/Hermes-Vespa-PM-Womens-Leather-Shoulder-Bag-Dark-Brown-BF576435
# Current CSV length (excluding header): 13
# https://mall.elady.com/item/title/Gucci-GG-Supreme-206501-MenWomen-PVC-Boston-Bag-BeigeBrown-BF576439
# Current CSV length (excluding header): 14
# https://mall.elady.com/item/title/Givenchy-Nightingale-Womens-Leather-HandbagShoulder-Bag-Black-BF576438
# Current CSV length (excluding header): 15
# https://mall.elady.com/item/title/Bvlgari-Logomania-22282-Womens-Canvas-Tote-Bag-Beige-BF576475
# Current CSV length (excluding header): 16
# https://mall.elady.com/item/title/Porter-Tanker-62276673-Mens-Nylon-Shoulder-BagTote-Bag-Silver-BF576471
# Current CSV length (excluding header): 17
# https://mall.elady.com/item/title/Porter-Tanker-Mens-Nylon-Briefcase-Black-BF576470
# Current CSV length (excluding header): 18
# https://mall.elady.com/item/title/Louis-Vuitton-Monogram-Alma-M51130-Womens-Handbag-Monogram-BF576457
# Current CSV length (excluding header): 19
# https://mall.elady.com/item/title/Herv-Chapelier-Womens-Coated-CanvasCanvas-Handbag-Red-Color-BF576354
# Current CSV length (excluding header): 20
# https://mall.elady.com/item/title/Louis-Vuitton-Monogram-Mini-Lucille-PM-M92684-Womens-Handbag-Beige-BF576451
# Current CSV length (excluding header): 21
# https://mall.elady.com/item/title/Cartier-WomenMen-Leather-Shoulder-Bag-Black-BF576355
# Current CSV length (excluding header): 22
# https://mall.elady.com/item/title/Celine-Big-Bag-Small-183313-Womens-Leather-HandbagShoulder-Bag-Wine-BF576353
# Current CSV length (excluding header): 23
# https://mall.elady.com/item/title/Dolce--Gabbana-MenWomen-Leather-HandbagShoulder-Bag-Black-BF576432
# Current CSV length (excluding header): 24
# https://mall.elady.com/item/title/Loewe-Amazona-36079002-Womens-SuedeLeather-Handbag-BeigeDark-Brown-BF576350
# Current CSV length (excluding header): 25
# https://mall.elady.com/item/title/Hermes-Pochette-Jet-MenWomen-Box-Calf-Leather-Clutch-Bag-Bordeaux-BF576352
# Current CSV length (excluding header): 26
# https://mall.elady.com/item/title/Louis-Vuitton-Monogram-Marly-Dragonne-PM-M51827-Womens-Clutch-Bag-Monogram-BF576482
# Current CSV length (excluding header): 27
# https://mall.elady.com/item/title/Louis-Vuitton-Epi-Blair-MM-M40329-Womens-HandbagShoulder-Bag-Noir-BF576483
# Current CSV length (excluding header): 28
# https://mall.elady.com/item/title/Louis-Vuitton-Monogram-Vernis-Melrose-Avenue-M93757-Womens-Handbag-Amarante-BF576380
# Current CSV length (excluding header): 29
# https://mall.elady.com/item/title/Loewe-Amazona-35212N03-Womens-Leather-HandbagShoulder-Bag-Bordeaux-BF576442
# Current CSV length (excluding header): 30
# https://mall.elady.com/item/title/Gucci-Bamboo-Daily-370831-Womens-LeatherBamboo-HandbagShoulder-Bag-Grayish-BF576440
# Current CSV length (excluding header): 31
# https://mall.elady.com/item/title/Dolce--Gabbana-DG-Girls-Womens-Leather-Shoulder-Bag-Silver-BF576449
# Current CSV length (excluding header): 32
# https://mall.elady.com/item/title/Chlo-Womens-Leather-Clutch-Bag-Coral-Pink-BF576474
# Current CSV length (excluding header): 33
# https://mall.elady.com/item/title/Burberry-8052887-MenWomen-Nylon-Fanny-Pack-Black-BF576476
# Current CSV length (excluding header): 34
# https://mall.elady.com/item/title/Porter-MenWomen-Leather-Backpack-Green-BF576472
# Current CSV length (excluding header): 35
# https://mall.elady.com/item/title/Louis-Vuitton-Monogram-Speedy-30-M41526-Womens-Handbag-Monogram-FVGZ000483
# Current CSV length (excluding header): 36
# https://mall.elady.com/item/title/Prada-KISSLOCK-CHAIN-CLUTCH-BAG-BT0383-Womens-SatinSuede-Shoulder-Bag-Black-BF576209
# Current CSV length (excluding header): 37
# https://mall.elady.com/item/title/Mulberry-Hampstead-Womens-Leather-Studded-HandbagShoulder-Bag-Navy-BF576184
# Current CSV length (excluding header): 38
# https://mall.elady.com/item/title/Bvlgari-Bvlgari-Bvlgari-Womens-Leather-Handbag-White-BF576185
# Current CSV length (excluding header): 39
# https://mall.elady.com/item/title/Russet-R-Mark-MenWomen-CanvasPVC-Tote-Bag-BlackBrown-BF576204
# Current CSV length (excluding header): 40
# https://mall.elady.com/item/title/Cartier-Mens-Leather-Briefcase-Black-BF576182
# Current CSV length (excluding header): 41
# https://mall.elady.com/item/title/Burberry-Quilting-Womens-Leather-Tote-Bag-Black-BF576183
# Current CSV length (excluding header): 42
# https://mall.elady.com/item/title/Furla-Linda-Mini-G6846-Womens-Leather-HandbagShoulder-Bag-Pink-BF576212
# Current CSV length (excluding header): 43
# https://mall.elady.com/item/title/Furla-Tessa-G7280-Womens-Leather-HandbagShoulder-Bag-Light-Blue-Gray-BF576238
# Current CSV length (excluding header): 44
# https://mall.elady.com/item/title/Celine-Luggage-Phantom-Womens-Leather-Handbag-Orange-BF576206
# Current CSV length (excluding header): 45
# https://mall.elady.com/item/title/Prada-Ribbon-Logo-Jacquard-Womens-LeatherJacquard-HandbagShoulder-Bag-Beige-BrownDark-Brown-BF576217
# Current CSV length (excluding header): 46
# https://mall.elady.com/item/title/Coach-Tate-Carryall-In-Colorblock-C2586-Womens-Leather-HandbagShoulder-Bag-BeigeGrayNavy-BF576215
# Current CSV length (excluding header): 47
# https://mall.elady.com/item/title/Cartier-C-De-Cartier-SM-Womens-Leather-HandbagShoulder-Bag-Gray-Purple-BF576270
# Current CSV length (excluding header): 48
# https://mall.elady.com/item/title/Jimmy-Choo-REBEL-Womens-Leather-Studded-HandbagShoulder-Bag-Black-BF576235
# Current CSV length (excluding header): 49
# https://mall.elady.com/item/title/Loewe-Gate-Womens-Leather-Shoulder-BagTote-Bag-Black-BF576223
# Current CSV length (excluding header): 50
