# %%
import requests
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
import undetected_chromedriver as uc
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
import time
import pandas as pd
from selenium.webdriver.common.keys import Keys

driver = uc.Chrome()

driver.maximize_window()
url = 'https://artrepreneur.com/search/artists?page=1&commercial=false&readyMade=false&searchDistanceMiles=20&'
driver.get(url)
wait = WebDriverWait(driver, 10)

# %%
i = 1
while True:
    
    page_url = f'https://artrepreneur.com/search/artists?page={i}&commercial=false&readyMade=false&searchDistanceMiles=124300&'
    print(f"Scraping page: {i}")
    i += 1
    driver.get(page_url)
   
    try:
        WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, '//ul[@class="pagination justify-content-center"]')))
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        next_button = soup.find('ul', class_='pagination justify-content-center').find_all('li')[-1].get('class')[-1]
        #next_button.click()
        if next_button == 'disabled':
            break
       
    except:
        break
    col_tags = soup.find_all('div', class_='card rounded-1 h-300')
    artists_url = []
    for j in range(1, len(col_tags) + 1):


        artist_element = driver.find_element(By.XPATH, f'//*[@id="relativeContainer"]/main/div[2]/div[1]/div/div[1]/div[2]/div[{j}]/div/div[1]/h5')
        driver.execute_script("arguments[0].scrollIntoView();", artist_element)
        time.sleep(1) 

        driver.execute_script("arguments[0].click();", artist_element)

        WebDriverWait(driver, 10).until(EC.url_changes(url))

    
        artist_url=driver.current_url
        print(f"Artist URL: {artist_url}")
        driver.get(artist_url)
        driver.implicitly_wait(10)
        WebDriverWait(driver, 10).until(
        EC.element_to_be_clickable((By.XPATH, '//a[@class="border-0 nav-link active"]'))
        ) 

        html_artist = driver.page_source
        soup_artist=BeautifulSoup(html_artist,'html.parser')

        follow_col_tags=soup_artist.find('div',class_='bg-lightGrey border-lightGrey d-flex p-3').find_all('div',class_='col')
        for follow_col_tag in follow_col_tags:
            if follow_col_tag.find('div', class_='fw-semiBold').text=='Followers':
                followers=follow_col_tag.find('strong').text
                print(followers," followers")
            if follow_col_tag.find('div', class_='fw-semiBold').text=='Following':
                following=follow_col_tag.find('strong').text
                print(following," following")

        if soup_artist.find('div', class_='fw-bold mt-2'):
            if soup_artist.find('div', class_='fw-bold mt-2').text == 'Bio':
                bio_element=soup_artist.find('div', class_='fw-bold mt-2')
                #artist_bio = bio_element.find_next_sibling('div', class_='profile-desc').find('p').text
                        #print(artist_bio)
            elif soup_artist.find('div', class_='desc-inner'):
                artist_bio = soup_artist.find('div', class_='desc-inner').text
                    #print(artist_bio)
            else:
                artist_bio = None
                    #print(artist_bio)
            time.sleep(5)
        try:
            artist_name = soup_artist.find('h1',class_ = 'bio-name mt-3 mb-1').text
            print(artist_name)
        except:
            artist_name = None


        try:
            artist_nationality = soup_artist.find('div',class_='profile-header__avatar-social').find('div',class_='font-12 text-center').text
            print(artist_nationality)
        except:
            artist_nationality = None
            time.sleep(5)
        try:
            
            WebDriverWait(driver, 10).until(
            EC.element_to_be_clickable((By.XPATH, '//span[@class="icon-search"]'))
            ) 
            driver.find_element('xpath', '//span[@class="icon-search"]').click()
            WebDriverWait(driver, 10).until(
                EC.element_to_be_clickable((By.XPATH, '//nav[@aria-label="Page navigation"]'))
            )
            html_asset_page = driver.page_source
            soup_asset_page=BeautifulSoup(html_asset_page,'html.parser')
            pagination_tag=soup_asset_page.find('ul',class_='pagination justify-content-center').find_all('li')

            for i in range(1,len(pagination_tag)-1):

                asset_div_tags=soup_asset_page.find('div',class_='react-photo-album react-photo-album--masonry').find_all('div',class_='subheadline1 text-break flex-1')

                for asset_div_tag in asset_div_tags:
                    asset_url='https://artrepreneur.com'+asset_div_tag.find('a').get('href')

                if i<len(pagination_tag)-2:
                    driver.execute_script("arguments[0].scrollIntoView();", driver.find_element(By.XPATH, "(//div[@class='position-relative'])[last()]"))
                    time.sleep(1)
                    next_button=driver.find_element('xpath', '//a[@class="page-link" and text()="Next"]')
                    next_button.click()
                driver.get(asset_url)
                WebDriverWait(driver, 10).until(
                    EC.element_to_be_clickable((By.XPATH, '//span[@class="me-1"]'))
                )


                asset_tags=[]
                try:
                    html_asset = driver.page_source
                    soup_asset =BeautifulSoup(html_asset,'html.parser')
                    span_tags=soup_asset.find('div',string='Search Terms').find_next_sibling().find('div',class_='h2-artwork').find_all('span')
                    for span_tag in span_tags:
                        tags=span_tag.text
                        asset_tags.append(tags)
                except:
                    pass
                try:
                    asset_title = soup_asset.find('div',class_='artwork-title my-2 text-break').text
                    print("asset title: ",asset_title)
                except:
                    asset_title=None
                
                try:  
                    seller_name = soup_asset.find('div',class_='font-15 text-break d-block d-sm-flex').find('a').text
                    print("seller: ",seller_name)
                except:
                    seller_name=None
                try: 
                    asset_description = soup_asset.find('div',class_='desc-inner').find('p').text
                    print("aaset description: ",asset_description)
                except:
                    asset_description=None
                try:
                    asset_created_date=soup_asset.find('div',string='Year Created').find_next_sibling('div').text
                    print("created: ",asset_created_date)
                except:
                    asset_created_date=None
                try:
                    asset_location=soup_asset.find('div',string='Location').find_next_sibling(string=True)
                    print("location: ",asset_location)
                except:
                    asset_location=None
                
                try:
                    asset_price_range=soup_asset.find('div',class_='col mx-auto').find('div').text
                    print(asset_title,"'s",asset_price_range)
                except:
                    asset_price_range=None
                

                driver.back()
                time.sleep(2)
            
            driver.get(page_url)
            
        except:
            pass
            
            driver.get(page_url)
# Out:
# Scraping page: 2
# Artist URL: https://artrepreneur.com/p/Globaldesigns
# 0  followers
# 0  following
# Dylan Elwood
# Phoenix, AZ, USA
# seller:  Dylan Elwood
# aaset description:  abstract surrealist black hole landscape
# created:  2024
# location:  Phoenix, AZ, USA
# None 's $100.00
# Artist URL: https://artrepreneur.com/p/RwcN6DpnyYEesqg59
# 0  followers
# 0  following
# Patricia Steinmann-Britt
# Switzerland
# seller:  Patricia Steinmann-Britt
# aaset description:  "Floral Universe" is an abstract painting that melds the organic beauty of flowers with the cosmic grandeur of planets and galaxies. The composition is a mesmerizing blend of swirling forms and vibrant colors, where each flower resembles a celestial body adrift in the vast expanse of space. The petals are painted in deep, rich tones of blues, purples, and blacks, evoking the mysterious and infinite nature of the cosmos.
# created:  2023
# None 's $2,450.00
# Artist URL: https://artrepreneur.com/p/mBiizLxZTh6TxF7nM
# 0  followers
# 0  following
# Natalia Laurel
# Russia
# seller:  Natalia Laurel
# created:  2022
# Artist URL: https://artrepreneur.com/p/eAz3ucmL7qeehPvrE
# 0  followers
# 0  following
# Sanna Fe
# Australia
# seller:  Sanna Fe
# aaset description:  Modern and contemporary design with clean rhythmic lines symbolizing uninhibited movement
# created:  2024
# Artist URL: https://artrepreneur.com/p/8GqeCsTzP5ymwuyBE
# created:  2024
# Artist URL: https://artrepreneur.com/p/page-davis
# 0  followers
# 0  following
# Page Davis
# Little Rock, AR, USA
# seller:  Page Davis
# created:  2022
# Artist URL: https://artrepreneur.com/p/Ryg4SCGKSnQi2H4ss
# 0  followers
# 0  following
# Ryan Doran
# San Diego, CA, USA
# seller:  Ryan Doran
# aaset description:  30"x48" Mixed Media and Spray Painted stencils
# created:  2024
# location:  San Diego
# None 's $1,200.00
# Artist URL: https://artrepreneur.com/p/YuTynxh85rw4qP5fX
# 0  followers
# 0  following
# Lisa Karachinsky
# Canada
# seller:  Lisa Karachinsky
# aaset description:  The leather and studs wall art with fashion appeal. Snake buckle anchors this standout piece, with pleated leather details + dome metallic studs. Made from premium Italian leather that is sourced ethically and Italian-made hardware. The studs' hardware has a mirror reflection, high sheen, and perfect polish. Long leather fringes are a distinguishing feature.
# created:  2024
# location:  Montreal, QC, Canada
# Artist URL: https://artrepreneur.com/p/CreativeAlchemist
# 0  followers
# 0  following
# Samm Starrs
# Brisbane QLD, Australia
# seller:  Samm Starrs
# aaset description:  Another view from a different part of the biggest and deepest lake on the fertile moon, Oberrhyon. We can see a juvenile dragon perched on one of the many fairie balancing stones that the fairies build to meditate upon. In the sky we can see the planet Oberrhyon orbits, Vahaluria. The fairies usually meditate on the full moon but are surreptitiously absent this full moon so the dragons have all taken their place. Perhaps the fairies are more present than we realise when we look closer and see a mischievous cat tempting fate by trying to swat at the dragon's tail. What else is a cat to do but play with such a toy that is willingly presented to it?
# created:  2024
# Artist URL: https://artrepreneur.com/p/fj9EMkDwxi4dfnnnP
# 0  followers
# 0  following
# Matt Palmer
# Adelaide SA, Australia
# Artist URL: https://artrepreneur.com/p/CjstSsYW9TZmsnKwp
# 0  followers
# 0  following
# Coffee Rain
# Sedona, AZ, USA
# seller:  Coffee Rain
# aaset description:  "The feline gaze is sure, and quick. It sees into dimensions unknown by man, but perhaps someday we'll train our eyes to see their perspective. The Curiosities of The Feline Gaze" - Coffee Rain
# created:  2023
# location:  Sedona, AZ, USA
# Artist URL: https://artrepreneur.com/p/48LKn8nFHgWt6rksQ
# 0  followers
# 0  following
# George Johnston
#
# seller:  George Johnston
# aaset description:  This painting is a tribute to my home city of Glasgow hosting the UCI World Championships in summer 2023. A moment in time where riders have to make a split-second decision on their tactics with so much at stake. The painting is deliberately fragmented and certain shapes in the wrong place to convey the movement and stress - in contrast to the bright colours and more abstract feel.
# created:  2023
# Artist URL: https://artrepreneur.com/p/Annie624E
# 0  followers
# 0  following
# ANN Marie ENGEBRECHT
# 9706 Alderson Street #4, Schofield, WI, USA
# seller:  ANN Marie ENGEBRECHT
# aaset description:  This is where some of my shapes that I have drawn comes into play.  Like the pod like shapes to the bulb like images mirroring themselves. Or the fern like aspects of the piece.  All seem to work together to make a piece fit for royalty!  And this is another phase of symmetry that I have gotten into.  Here and there, in many different ways. Some you could say even look like quilts. (Obviously not this one....LOL)   I also like to take away the dramatic way the white of the paper has a way of outshining the whole piece.  That's when I use water color the most to shade it a bit. Believe me that is a work in progress and a technique that is ever evolving .
# created:  2024
# Artist URL: https://artrepreneur.com/p/xxiAD6d799CSJ8S2g
# 0  followers
# 0  following
# Yasuo Oda
# Columbia, MD, USA
# seller:  Yasuo Oda
# aaset description:  https://www.youtube.com/watch?v=tDEzmaZHuS0
# created:  2024
# location:  Columbia, MD, USA
# None 's $540.00
# Artist URL: https://artrepreneur.com/p/QNzAdMn9HHZz3vB6K
# 0  followers
# 0  following
# Paolo Iarussi
# West Hollywood, CA 90046, USA
# seller:  Paolo Iarussi
# aaset description:  Mind’s Eye 2 is an illustration of an organic eye, entrapped in the rigidness of linear cubes. It represents the SELF and it’s inability to fully express itself in the parameters set by society. The eye is hopeful and colorful, like our minds, and it’s seeping through the hard edges of the expectations set for us by others. This piece is painted on both sides.
# created:  2024
# location:  West Hollywood, CA 90046, USA
# Artist URL: https://artrepreneur.com/p/5yHYP8RueXc9vpHmv
# 0  followers
# 0  following
# Christie Cavit
#
# Artist URL: https://artrepreneur.com/p/ostaraphotography
# 0  followers
# 0  following
# Evie K.
# Pittsburgh, Pennsylvania, USA
# seller:  Evie K.
# aaset description:  "Seelie's Embrace Number 1" is a captivating photograph that brings to life the enchanting beauty of Love-in-a-Mist. This exquisite member of the buttercup family is known for its delicate, star-like blossoms that symbolize unrequited love. In many cultures, Love-in-a-Mist is also revered for its protective qualities, believed to ward off evil spirits.
# created:  2024
# Artist URL: https://artrepreneur.com/p/NMsHcJBWkk5dFybH5
# 0  followers
# 0  following
# Bryan R Barton
# Alexandria, Virginia, USA
# Artist URL: https://artrepreneur.com/p/SharnBassi
# 0  followers
# 0  following
# Sharn Bassi
# Toronto, ON, Canada
# seller:  Sharn Bassi
# aaset description:  “Many Paths” … a series of works illustrating the different journeys we all take when in human form. All humanity yearning for connection with the divine.
# created:  2023
# Artist URL: https://artrepreneur.com/p/WBsFGse9tvZkjxFHC
# 0  followers
# 0  following
# Heather Ipock
# Beaufort, NC 28516, USA
# seller:  Heather Ipock
# aaset description:  An illustration of a multicolored crab is depicted in a walking pose against a tan background. The crab features shades of blue, green, yellow, and red, designed to be viewed from various angles.
# created:  2023
# location:  New Bern, NC, USA
# Scraping page: 2
# Artist URL: https://artrepreneur.com/p/Globaldesigns
# 0  followers
# 0  following
# Dylan Elwood
# Phoenix, AZ, USA
# seller:  Dylan Elwood
# aaset description:  abstract surrealist black hole landscape
# created:  2024
# location:  Phoenix, AZ, USA
# None 's $100.00
# Artist URL: https://artrepreneur.com/p/RwcN6DpnyYEesqg59
# 0  followers
# 0  following
# Patricia Steinmann-Britt
# Switzerland
# seller:  Patricia Steinmann-Britt
# aaset description:  "Floral Universe" is an abstract painting that melds the organic beauty of flowers with the cosmic grandeur of planets and galaxies. The composition is a mesmerizing blend of swirling forms and vibrant colors, where each flower resembles a celestial body adrift in the vast expanse of space. The petals are painted in deep, rich tones of blues, purples, and blacks, evoking the mysterious and infinite nature of the cosmos.
# created:  2023
# None 's $2,450.00
# Artist URL: https://artrepreneur.com/p/mBiizLxZTh6TxF7nM
# aaset description:  This is where some of my shapes that I have drawn comes into play.  Like the pod like shapes to the bulb like images mirroring themselves. Or the fern like aspects of the piece.  All seem to work together to make a piece fit for royalty!  And this is another phase of symmetry that I have gotten into.  Here and there, in many different ways. Some you could say even look like quilts. (Obviously not this one....LOL)   I also like to take away the dramatic way the white of the paper has a way of outshining the whole piece.  That's when I use water color the most to shade it a bit. Believe me that is a work in progress and a technique that is ever evolving .
# created:  2024
# Artist URL: https://artrepreneur.com/p/xxiAD6d799CSJ8S2g
# 0  followers
# 0  following
# Yasuo Oda
# Columbia, MD, USA
# seller:  Yasuo Oda
# aaset description:  https://www.youtube.com/watch?v=tDEzmaZHuS0
# created:  2024
# location:  Columbia, MD, USA
# None 's $540.00
# Artist URL: https://artrepreneur.com/p/QNzAdMn9HHZz3vB6K
# 0  followers
# 0  following
# Paolo Iarussi
# West Hollywood, CA 90046, USA
# seller:  Paolo Iarussi
# aaset description:  Mind’s Eye 2 is an illustration of an organic eye, entrapped in the rigidness of linear cubes. It represents the SELF and it’s inability to fully express itself in the parameters set by society. The eye is hopeful and colorful, like our minds, and it’s seeping through the hard edges of the expectations set for us by others. This piece is painted on both sides.
# created:  2024
# location:  West Hollywood, CA 90046, USA
# Artist URL: https://artrepreneur.com/p/5yHYP8RueXc9vpHmv
# 0  followers
# 0  following
# Christie Cavit
#
# Artist URL: https://artrepreneur.com/p/ostaraphotography
# 0  followers
# 0  following
# Evie K.
# Pittsburgh, Pennsylvania, USA
# seller:  Evie K.
# aaset description:  "Seelie's Embrace Number 1" is a captivating photograph that brings to life the enchanting beauty of Love-in-a-Mist. This exquisite member of the buttercup family is known for its delicate, star-like blossoms that symbolize unrequited love. In many cultures, Love-in-a-Mist is also revered for its protective qualities, believed to ward off evil spirits.
# created:  2024
# Artist URL: https://artrepreneur.com/p/NMsHcJBWkk5dFybH5
# 0  followers
# 0  following
# Bryan R Barton
# Alexandria, Virginia, USA
# Artist URL: https://artrepreneur.com/p/SharnBassi
# 0  followers
# 0  following
# Sharn Bassi
# Toronto, ON, Canada
# seller:  Sharn Bassi
# aaset description:  “Many Paths” … a series of works illustrating the different journeys we all take when in human form. All humanity yearning for connection with the divine.
# created:  2023
# Artist URL: https://artrepreneur.com/p/WBsFGse9tvZkjxFHC
# 0  followers
# 0  following
# Heather Ipock
# Beaufort, NC 28516, USA
# seller:  Heather Ipock
# aaset description:  An illustration of a multicolored crab is depicted in a walking pose against a tan background. The crab features shades of blue, green, yellow, and red, designed to be viewed from various angles.
# created:  2023
# location:  New Bern, NC, USA
# Scraping page: 2
# Artist URL: https://artrepreneur.com/p/Globaldesigns
# 0  followers
# 0  following
# Dylan Elwood
# Phoenix, AZ, USA
# seller:  Dylan Elwood
# aaset description:  abstract surrealist black hole landscape
# created:  2024
# location:  Phoenix, AZ, USA
# None 's $100.00
# Artist URL: https://artrepreneur.com/p/RwcN6DpnyYEesqg59
# 0  followers
# 0  following
# Patricia Steinmann-Britt
# Switzerland
# seller:  Patricia Steinmann-Britt
# aaset description:  This painting is a tribute to my home city of Glasgow hosting the UCI World Championships in summer 2023. A moment in time where riders have to make a split-second decision on their tactics with so much at stake. The painting is deliberately fragmented and certain shapes in the wrong place to convey the movement and stress - in contrast to the bright colours and more abstract feel.
# created:  2023
# Artist URL: https://artrepreneur.com/p/Annie624E
# 0  followers
# 0  following
# ANN Marie ENGEBRECHT
# 9706 Alderson Street #4, Schofield, WI, USA
# seller:  ANN Marie ENGEBRECHT
# aaset description:  This is where some of my shapes that I have drawn comes into play.  Like the pod like shapes to the bulb like images mirroring themselves. Or the fern like aspects of the piece.  All seem to work together to make a piece fit for royalty!  And this is another phase of symmetry that I have gotten into.  Here and there, in many different ways. Some you could say even look like quilts. (Obviously not this one....LOL)   I also like to take away the dramatic way the white of the paper has a way of outshining the whole piece.  That's when I use water color the most to shade it a bit. Believe me that is a work in progress and a technique that is ever evolving .
# created:  2024
# Artist URL: https://artrepreneur.com/p/xxiAD6d799CSJ8S2g
# 0  followers
# 0  following
# Yasuo Oda
# Columbia, MD, USA
# seller:  Yasuo Oda
# aaset description:  https://www.youtube.com/watch?v=tDEzmaZHuS0
# created:  2024
# location:  Columbia, MD, USA
# None 's $540.00
# Artist URL: https://artrepreneur.com/p/QNzAdMn9HHZz3vB6K
# 0  followers
# 0  following
# Paolo Iarussi
# West Hollywood, CA 90046, USA
# seller:  Paolo Iarussi
# aaset description:  Mind’s Eye 2 is an illustration of an organic eye, entrapped in the rigidness of linear cubes. It represents the SELF and it’s inability to fully express itself in the parameters set by society. The eye is hopeful and colorful, like our minds, and it’s seeping through the hard edges of the expectations set for us by others. This piece is painted on both sides.
# created:  2024
# location:  West Hollywood, CA 90046, USA
# Artist URL: https://artrepreneur.com/p/5yHYP8RueXc9vpHmv
# 0  followers
# 0  following
# Christie Cavit
#
# Artist URL: https://artrepreneur.com/p/ostaraphotography
# 0  followers
# 0  following
# Evie K.
# Pittsburgh, Pennsylvania, USA
# seller:  Evie K.
# aaset description:  "Seelie's Embrace Number 1" is a captivating photograph that brings to life the enchanting beauty of Love-in-a-Mist. This exquisite member of the buttercup family is known for its delicate, star-like blossoms that symbolize unrequited love. In many cultures, Love-in-a-Mist is also revered for its protective qualities, believed to ward off evil spirits.
# created:  2024
# Artist URL: https://artrepreneur.com/p/NMsHcJBWkk5dFybH5
# 0  followers
# 0  following
# Bryan R Barton
# Alexandria, Virginia, USA
# Artist URL: https://artrepreneur.com/p/SharnBassi
# 0  followers
# 0  following
# Sharn Bassi
# Toronto, ON, Canada
# seller:  Sharn Bassi
# aaset description:  “Many Paths” … a series of works illustrating the different journeys we all take when in human form. All humanity yearning for connection with the divine.
# created:  2023
# Artist URL: https://artrepreneur.com/p/WBsFGse9tvZkjxFHC
# 0  followers
# 0  following
# Heather Ipock
# Beaufort, NC 28516, USA
# seller:  Heather Ipock
# aaset description:  An illustration of a multicolored crab is depicted in a walking pose against a tan background. The crab features shades of blue, green, yellow, and red, designed to be viewed from various angles.
# created:  2023
# location:  New Bern, NC, USA
# Scraping page: 2
# Artist URL: https://artrepreneur.com/p/Globaldesigns
# 0  followers
# 0  following
# Dylan Elwood
# aaset description:  "The feline gaze is sure, and quick. It sees into dimensions unknown by man, but perhaps someday we'll train our eyes to see their perspective. The Curiosities of The Feline Gaze" - Coffee Rain
# created:  2023
# location:  Sedona, AZ, USA
# Artist URL: https://artrepreneur.com/p/48LKn8nFHgWt6rksQ
# 0  followers
# 0  following
# George Johnston
#
# seller:  George Johnston
# aaset description:  This painting is a tribute to my home city of Glasgow hosting the UCI World Championships in summer 2023. A moment in time where riders have to make a split-second decision on their tactics with so much at stake. The painting is deliberately fragmented and certain shapes in the wrong place to convey the movement and stress - in contrast to the bright colours and more abstract feel.
# created:  2023
# Artist URL: https://artrepreneur.com/p/Annie624E
# 0  followers
# 0  following
# ANN Marie ENGEBRECHT
# 9706 Alderson Street #4, Schofield, WI, USA
# seller:  ANN Marie ENGEBRECHT
# aaset description:  This is where some of my shapes that I have drawn comes into play.  Like the pod like shapes to the bulb like images mirroring themselves. Or the fern like aspects of the piece.  All seem to work together to make a piece fit for royalty!  And this is another phase of symmetry that I have gotten into.  Here and there, in many different ways. Some you could say even look like quilts. (Obviously not this one....LOL)   I also like to take away the dramatic way the white of the paper has a way of outshining the whole piece.  That's when I use water color the most to shade it a bit. Believe me that is a work in progress and a technique that is ever evolving .
# created:  2024
# Artist URL: https://artrepreneur.com/p/xxiAD6d799CSJ8S2g
# 0  followers
# 0  following
# Yasuo Oda
# Columbia, MD, USA
# seller:  Yasuo Oda
# aaset description:  https://www.youtube.com/watch?v=tDEzmaZHuS0
# created:  2024
# location:  Columbia, MD, USA
# None 's $540.00
# Artist URL: https://artrepreneur.com/p/QNzAdMn9HHZz3vB6K
# 0  followers
# 0  following
# Paolo Iarussi
# West Hollywood, CA 90046, USA
# seller:  Paolo Iarussi
# aaset description:  Mind’s Eye 2 is an illustration of an organic eye, entrapped in the rigidness of linear cubes. It represents the SELF and it’s inability to fully express itself in the parameters set by society. The eye is hopeful and colorful, like our minds, and it’s seeping through the hard edges of the expectations set for us by others. This piece is painted on both sides.
# created:  2024
# location:  West Hollywood, CA 90046, USA
# Artist URL: https://artrepreneur.com/p/5yHYP8RueXc9vpHmv
# 0  followers
# 0  following
# Christie Cavit
#
# Artist URL: https://artrepreneur.com/p/ostaraphotography
# 0  followers
# 0  following
# Evie K.
# Pittsburgh, Pennsylvania, USA
# seller:  Evie K.
# aaset description:  "Seelie's Embrace Number 1" is a captivating photograph that brings to life the enchanting beauty of Love-in-a-Mist. This exquisite member of the buttercup family is known for its delicate, star-like blossoms that symbolize unrequited love. In many cultures, Love-in-a-Mist is also revered for its protective qualities, believed to ward off evil spirits.
# created:  2024
# Artist URL: https://artrepreneur.com/p/NMsHcJBWkk5dFybH5
# 0  followers
# 0  following
# Bryan R Barton
# Alexandria, Virginia, USA
# Artist URL: https://artrepreneur.com/p/SharnBassi
# 0  followers
# 0  following
# Sharn Bassi
# Toronto, ON, Canada
# seller:  Sharn Bassi
# aaset description:  “Many Paths” … a series of works illustrating the different journeys we all take when in human form. All humanity yearning for connection with the divine.
# created:  2023
# Artist URL: https://artrepreneur.com/p/WBsFGse9tvZkjxFHC
# 0  followers
# 0  following
# Heather Ipock
# Beaufort, NC 28516, USA
# seller:  Heather Ipock
# aaset description:  An illustration of a multicolored crab is depicted in a walking pose against a tan background. The crab features shades of blue, green, yellow, and red, designed to be viewed from various angles.
# created:  2023
# location:  New Bern, NC, USA
# Scraping page: 2
# Artist URL: https://artrepreneur.com/p/Globaldesigns
# 0  followers
# 0  following
# Dylan Elwood
# Phoenix, AZ, USA
# seller:  Dylan Elwood
# aaset description:  abstract surrealist black hole landscape
# created:  2024
# location:  Phoenix, AZ, USA
# None 's $100.00
# Artist URL: https://artrepreneur.com/p/RwcN6DpnyYEesqg59
# 0  followers
# 0  following
# Patricia Steinmann-Britt
# Switzerland
# seller:  Patricia Steinmann-Britt
# aaset description:  "Floral Universe" is an abstract painting that melds the organic beauty of flowers with the cosmic grandeur of planets and galaxies. The composition is a mesmerizing blend of swirling forms and vibrant colors, where each flower resembles a celestial body adrift in the vast expanse of space. The petals are painted in deep, rich tones of blues, purples, and blacks, evoking the mysterious and infinite nature of the cosmos.
# created:  2023
# None 's $2,450.00
# Artist URL: https://artrepreneur.com/p/mBiizLxZTh6TxF7nM
# 0  followers
# 0  following
# Natalia Laurel
# Russia
# seller:  Natalia Laurel
# created:  2022
# Artist URL: https://artrepreneur.com/p/eAz3ucmL7qeehPvrE
# 0  followers
# 0  following
# Sanna Fe
# Australia
# seller:  Sanna Fe
# aaset description:  Modern and contemporary design with clean rhythmic lines symbolizing uninhibited movement
# created:  2024
# Artist URL: https://artrepreneur.com/p/8GqeCsTzP5ymwuyBE
# 0  followers
# 0  following
# Andrea Boff
# North Carolina, USA
# seller:  Andrea Boff
# aaset description:  "Bouquet of Sparrows" is a resurrection theme that I use often. You will see some "old junk" that gets a new life, and in this case, it's a broken violin that becomes home to a family of sparrows. Its fun to think of how that all happened at the base of tree.
# created:  2024
# location:  North Carolina, USA
# None 's $399.00
# Artist URL: https://artrepreneur.com/p/kiramarlett
# 0  followers
# 0  following
# Kira Marlett
# United States
# Artist URL: https://artrepreneur.com/p/iESsi79wW5pYQNKKn
# 0  followers
# 0  following
# Rebecka Hess
# Savannah, GA, USA
# seller:  Rebecka Hess
# aaset description:  Oil on stretched black canvas. Flow of the water gives the painting great motion.
# created:  2024
# location:  Savannah, GA, USA
# None 's $1,255.00
# Artist URL: https://artrepreneur.com/p/Lauren-tatta
# 0  followers
# 0  following
# Lauren Tatta
# Meriden, CT, USA
# seller:  Lauren Tatta
# created:  2024
# location:  Meriden, CT, USA
# Artist URL: https://artrepreneur.com/p/TY3RwbvJSCd5u6Mif
# 0  followers
# 0  following
# Viktoria Zakharava
# Bologna, BO, Italia
# seller:  Viktoria Zakharava
# created:  2023
# location:  Bologna, BO, Italia
# Artist URL: https://artrepreneur.com/p/hXBzXuFNeu77iNAic
# 0  followers
# 0  following
# Nadia Caldwell
# Miami, FL, USA
# Artist URL: https://artrepreneur.com/p/BonnieSprungArtist
# 0  followers
# 0  following
# Bonnie Sprung
# USA
# seller:  Bonnie Sprung
# aaset description:  Acrylic/Oil on Canvas covered CD’s.   21 CD's
# created:  2024
# Artist URL: https://artrepreneur.com/p/fj9EMkDwxi4dfnnnP
# 0  followers
# 0  following
# Matt Palmer
# Adelaide SA, Australia
# Artist URL: https://artrepreneur.com/p/CjstSsYW9TZmsnKwp
# 0  followers
# 0  following
# Coffee Rain
# Sedona, AZ, USA
# seller:  Coffee Rain
# aaset description:  "The feline gaze is sure, and quick. It sees into dimensions unknown by man, but perhaps someday we'll train our eyes to see their perspective. The Curiosities of The Feline Gaze" - Coffee Rain
# created:  2023
# location:  Sedona, AZ, USA
# Artist URL: https://artrepreneur.com/p/48LKn8nFHgWt6rksQ
# 0  followers
# 0  following
# George Johnston
#
# seller:  George Johnston
# aaset description:  This painting is a tribute to my home city of Glasgow hosting the UCI World Championships in summer 2023. A moment in time where riders have to make a split-second decision on their tactics with so much at stake. The painting is deliberately fragmented and certain shapes in the wrong place to convey the movement and stress - in contrast to the bright colours and more abstract feel.
# created:  2023
# Artist URL: https://artrepreneur.com/p/Annie624E
# 0  followers
# 0  following
# ANN Marie ENGEBRECHT
# 9706 Alderson Street #4, Schofield, WI, USA
# seller:  ANN Marie ENGEBRECHT
# aaset description:  This is where some of my shapes that I have drawn comes into play.  Like the pod like shapes to the bulb like images mirroring themselves. Or the fern like aspects of the piece.  All seem to work together to make a piece fit for royalty!  And this is another phase of symmetry that I have gotten into.  Here and there, in many different ways. Some you could say even look like quilts. (Obviously not this one....LOL)   I also like to take away the dramatic way the white of the paper has a way of outshining the whole piece.  That's when I use water color the most to shade it a bit. Believe me that is a work in progress and a technique that is ever evolving .
# created:  2024
# Artist URL: https://artrepreneur.com/p/xxiAD6d799CSJ8S2g
# 0  followers
# 0  following
# Yasuo Oda
# Columbia, MD, USA
# seller:  Yasuo Oda
# aaset description:  https://www.youtube.com/watch?v=tDEzmaZHuS0
# created:  2024
# location:  Columbia, MD, USA
# None 's $540.00
# Artist URL: https://artrepreneur.com/p/QNzAdMn9HHZz3vB6K
# 0  followers
# 0  following
# Paolo Iarussi
# West Hollywood, CA 90046, USA
# seller:  Paolo Iarussi
# aaset description:  Mind’s Eye 2 is an illustration of an organic eye, entrapped in the rigidness of linear cubes. It represents the SELF and it’s inability to fully express itself in the parameters set by society. The eye is hopeful and colorful, like our minds, and it’s seeping through the hard edges of the expectations set for us by others. This piece is painted on both sides.
# created:  2024
# location:  West Hollywood, CA 90046, USA
# Artist URL: https://artrepreneur.com/p/5yHYP8RueXc9vpHmv
# 0  followers
# 0  following
# Christie Cavit
#
# Artist URL: https://artrepreneur.com/p/ostaraphotography
# 0  followers
# 0  following
# Evie K.
# Pittsburgh, Pennsylvania, USA
# seller:  Evie K.
# aaset description:  "Seelie's Embrace Number 1" is a captivating photograph that brings to life the enchanting beauty of Love-in-a-Mist. This exquisite member of the buttercup family is known for its delicate, star-like blossoms that symbolize unrequited love. In many cultures, Love-in-a-Mist is also revered for its protective qualities, believed to ward off evil spirits.
# created:  2024
# Artist URL: https://artrepreneur.com/p/NMsHcJBWkk5dFybH5
# 0  followers
# 0  following
# Bryan R Barton
# Alexandria, Virginia, USA
# Artist URL: https://artrepreneur.com/p/SharnBassi
# 0  followers
# 0  following
# Sharn Bassi
# Toronto, ON, Canada
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[9], line 81
#      79 try:
# ---> 81     WebDriverWait(driver, 10).until(
#      82     EC.element_to_be_clickable((By.XPATH, '//span[@class="icon-search"]'))
#      83     )
#      84     driver.find_element('xpath', '//span[@class="icon-search"]').click()
#
# File ~\anaconda3\envs\env\lib\site-packages\selenium\webdriver\support\wait.py:96, in WebDriverWait.until(self, method, message)
#      95 try:
# ---> 96     value = method(self._driver)
#      97     if value:
#
# File ~\anaconda3\envs\env\lib\site-packages\selenium\webdriver\support\expected_conditions.py:363, in element_to_be_clickable.<locals>._predicate(driver)
#     362 if not isinstance(target, WebElement):  # if given locator instead of WebElement
# --> 363     target = driver.find_element(*target)  # grab element at locator
#     364 element = visibility_of(target)(driver)
#
# File ~\anaconda3\envs\env\lib\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\envs\env\lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#
# File ~\anaconda3\envs\env\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=127.0.6533.89)
# Stacktrace:
# 	GetHandleVerifier [0x003E8923+23283]
# 	(No symbol) [0x003AE934]
# 	(No symbol) [0x002E0733]
# 	(No symbol) [0x002BD2E3]
# 	(No symbol) [0x0034A64F]
# 	(No symbol) [0x0035C686]
# 	(No symbol) [0x003441B6]
# 	(No symbol) [0x00318017]
# 	(No symbol) [0x0031890D]
# 	GetHandleVerifier [0x004DA5E3+1013683]
# 	GetHandleVerifier [0x004E3E3C+1052684]
# 	GetHandleVerifier [0x004DD4A4+1025652]
# 	GetHandleVerifier [0x0040EA2B+179195]
# 	(No symbol) [0x003B6833]
# 	(No symbol) [0x003B3198]
# 	(No symbol) [0x003B3337]
# 	(No symbol) [0x003AB4BE]
# 	BaseThreadInitThunk [0x7738FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x776880CE+286]
# 	RtlGetAppContainerNamedObjectPath [0x7768809E+238]
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[9], line 162
#     159 except:
#     160     pass
# --> 162     driver.get(page_url)
#
# File ~\anaconda3\envs\env\lib\site-packages\undetected_chromedriver\__init__.py:665, in Chrome.get(self, url)
#     662 def get(self, url):
#     663     # if self._get_cdc_props():
#     664     #     self._hook_remove_cdc_props()
# --> 665     return super().get(url)
#
# File ~\anaconda3\envs\env\lib\site-packages\selenium\webdriver\remote\webdriver.py:356, in WebDriver.get(self, url)
#     354 def get(self, url: str) -> None:
#     355     """Loads a web page in the current browser session."""
# --> 356     self.execute(Command.GET, {"url": url})
#
# File ~\anaconda3\envs\env\lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~\anaconda3\envs\env\lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=127.0.6533.89)
# Stacktrace:
# 	GetHandleVerifier [0x003E8923+23283]
# 	(No symbol) [0x003AE934]
# 	(No symbol) [0x002E0733]
# 	(No symbol) [0x002BD2E3]
# 	(No symbol) [0x0034A64F]
# 	(No symbol) [0x0035C686]
# 	(No symbol) [0x003441B6]
# 	(No symbol) [0x00318017]
# 	(No symbol) [0x0031890D]
# 	GetHandleVerifier [0x004DA5E3+1013683]
# 	GetHandleVerifier [0x004E3E3C+1052684]
# 	GetHandleVerifier [0x004DD4A4+1025652]
# 	GetHandleVerifier [0x0040EA2B+179195]
# 	(No symbol) [0x003B6833]
# 	(No symbol) [0x003B3198]
# 	(No symbol) [0x003B3337]
# 	(No symbol) [0x003AB4BE]
# 	BaseThreadInitThunk [0x7738FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x776880CE+286]
# 	RtlGetAppContainerNamedObjectPath [0x7768809E+238]
